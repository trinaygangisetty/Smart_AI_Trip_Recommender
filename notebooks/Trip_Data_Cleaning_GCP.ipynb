# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !pip install --upgrade google-cloud-storage
# Out:
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.11/dist-packages (2.19.0)
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-3.1.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.38.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.25.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.32.3)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=2.15.0->google-cloud-storage) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=2.15.0->google-cloud-storage) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=2.15.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.6.15)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.1)
# Downloading google_cloud_storage-3.1.1-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: google-cloud-storage
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.19.0
#     Uninstalling google-cloud-storage-2.19.0:
#       Successfully uninstalled google-cloud-storage-2.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-aiplatform 1.99.0 requires google-cloud-storage<3.0.0,>=1.32.0, but you have google-cloud-storage 3.1.1 which is incompatible.
# Successfully installed google-cloud-storage-3.1.1

# %%
from google.cloud import storage

# %%
client = storage.Client(project= 'trip-recommendation-project')
bucket = client.get_bucket('trip-data-cleaning')

# %%
blobs = list(bucket.list_blobs())

# %%
blobs
# Out:
# [<Blob: trip-data-cleaning, destinations.csv, 1751235090758947>,
#  <Blob: trip-data-cleaning, members.csv, 1751235091072110>,
#  <Blob: trip-data-cleaning, members_clean.csv, 1751235115560472>,
#  <Blob: trip-data-cleaning, trips.csv, 1751235090870536>,
#  <Blob: trip-data-cleaning, weather.csv, 1751235090709155>]

# %%
csv_files = [blob.name for blob in blobs if blob.name.endswith('.csv')]

# %%
csv_files
# Out:
# ['destinations.csv',
#  'members.csv',
#  'members_clean.csv',
#  'trips.csv',
#  'weather.csv']

# %%
if not csv_files:
  print("no '.csv' files are found in the bucket!")
else:
  for file in csv_files:
    blob = bucket.blob(file)
    blob.download_to_filename(file)
    print(f"Downloaded: {file}")
# Out:
# Downloaded: destinations.csv
# Downloaded: members.csv
# Downloaded: members_clean.csv
# Downloaded: trips.csv
# Downloaded: weather.csv

# %% [markdown]
# # Members.CSV File Cleaning

# %%
# cleaning members.csv first
import numpy as np
import pandas as pd

df_members = pd.read_csv('members.csv')

# %%
df_members.shape
# Out:
# (1005, 9)

# %%
df_members.head()
# Out:
#    member_id              name      age         location  travel_budget  \
# 0       1685  michael williams       71   Stevenstad- IA         646000
# 1       1614   Danielle george       50  Jessicabury, NC         153000
# 2       1602      denise brock       22  Salinasfort- ND         155000
# 3       1502      Terry holmes  unknown  South Megan- MP         403000
# 4       1341   michelle walker       25   Davidburgh, CO         693000
#
#     signup_date preference  num_dependents  has_passport
# 0    17/07/2021     luxury               3         False
# 1    2024-04-06  adventure               0          True
# 2    2024-09-23      beach               3          True
# 3  Apr 24, 2024      beach               3          True
# 4    22/01/2023   cultural               3          True

# %% [markdown]
# ### Cleaning Plan for `members.csv` (To-Do)
#
# Before using the `members.csv` data for analysis or joining, I need to perform the following cleaning steps:
#
# | Column           | Cleaning To-Do                                                                 |
# |------------------|----------------------------------------------------------------------------------|
# | `member_id`      | Convert to integer, ensure values are unique and non-null.                      |
# | `name`           | Strip whitespace and apply `.title()` to standardize casing.                    |
# | `age`            | Convert to numeric and filter valid range (18–100).                             |
# | `location`       | Remove non-alphabetic characters and standardize to `"City, ST"` format.        |
# | `travel_budget`  | Ensure numeric, drop missing or extreme values (outside $50k–$1M).              |
# | `signup_date`    | Parse mixed formats to `YYYY-MM-DD`, drop rows with invalid dates.              |
# | `preference`     | Normalize to lowercase and keep only valid values like adventure, beach, etc.   |
# | `num_dependents` | Convert to integer, fill NAs with 0, and drop negatives.                        |
# | `has_passport`   | Map text to boolean (`True`/`False`), drop rows with invalid values.            |
#
# I'll apply each of these in Pandas using `.astype()`, `.str.strip()`, `.to_numeric()`, `.to_datetime()`, `.map()`, and filtering functions.

# %%
# code

# name variable cleaning

df_members['name'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Name Variable Cleaning

# %%
df_members['name'] = df_members['name'].astype(str).str.strip().str.title()

# %%
type(df_members['name'].iloc[0])
# Out:
# str

# %% [markdown]
# ## Age Variable Cleaning

# %%
# age variable cleaning

type(df_members['age'].iloc[0])
# Out:
# str

# %%
df_members['age'].unique()
# Out:
# array(['71', '50', '22', 'unknown', '25', '34', '68', '33', '74', '54',
#        '-3', nan, '55', '57', '56', '49', '75', '27', '63', '62', '39',
#        '44', '70', '67', '21', '36', '77', '58', '61', '48', '20', '66',
#        '28', '24', '76', '64', '45', '30', '52', '41', '42', '47', '43',
#        '78', '65', '80', '46', '18', '59', '23', '73', '53', '60', '26',
#        '72', '38', '37', '29', '31', '51', '69', '32', '40', '35', '19',
#        '79'], dtype=object)

# %%
df_members['age'] = df_members['age'].replace(['','unknown','-3'], np.nan)

# %%
df_members['age'].value_counts(dropna=False)
# Out:
# age
# NaN    95
# 50     23
# 43     22
# 76     21
# 64     21
#        ..
# 31     10
# 62      9
# 72      9
# 35      9
# 19      7
# Name: count, Length: 64, dtype: int64

# %%
df_members['age'] = pd.to_numeric(df_members['age']) # converting str to int

# %%
# imputing the missing values with median of the particular preference group to look more realistic

df_members['age'] = df_members.groupby('preference')['age'].transform(
    lambda x: x.fillna(x.median())
)

# %%
df_members['age'].value_counts(dropna=False)
# Out:
# age
# 48.0    48
# 48.5    38
# 50.0    38
# 43.0    22
# 64.0    21
#         ..
# 31.0    10
# 62.0     9
# 72.0     9
# 35.0     9
# 19.0     7
# Name: count, Length: 65, dtype: int64

# %%
df_members['age'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Location Variable Cleaning

# %%
df_members['location'].head(5)
# Out:
# 0     Stevenstad- IA
# 1    Jessicabury, NC
# 2    Salinasfort- ND
# 3    South Megan- MP
# 4     Davidburgh, CO
# Name: location, dtype: object

# %%
df_members['location'] = df_members['location'].str.replace(r'[\-/]', ',', regex=True)

# %%
df_members['location'].head(5)
# Out:
# 0     Stevenstad, IA
# 1    Jessicabury, NC
# 2    Salinasfort, ND
# 3    South Megan, MP
# 4     Davidburgh, CO
# Name: location, dtype: object

# %%
df_members[['city', 'state']] = df_members['location'].str.extract(r'^\s*([\w\s]+)\s*,\s*([A-Z]{2})\s*$')

# %%
df_members.head(3)
# Out:
#    member_id              name   age         location  travel_budget  \
# 0       1685  Michael Williams  71.0   Stevenstad, IA         646000
# 1       1614   Danielle George  50.0  Jessicabury, NC         153000
# 2       1602      Denise Brock  22.0  Salinasfort, ND         155000
#
#   signup_date preference  num_dependents  has_passport         city state
# 0  17/07/2021     luxury               3         False   Stevenstad    IA
# 1  2024-04-06  adventure               0          True  Jessicabury    NC
# 2  2024-09-23      beach               3          True  Salinasfort    ND

# %%
df_members.drop(columns = 'location', inplace = True)

# %%
df_members['city'] = df_members['city'].str.strip().str.title()
df_members['state'] = df_members['state'].str.strip().str.upper()

# %%
df_members.head(5)
# Out:
#    member_id              name   age  travel_budget   signup_date preference  \
# 0       1685  Michael Williams  71.0         646000    17/07/2021     luxury
# 1       1614   Danielle George  50.0         153000    2024-04-06  adventure
# 2       1602      Denise Brock  22.0         155000    2024-09-23      beach
# 3       1502      Terry Holmes  50.0         403000  Apr 24, 2024      beach
# 4       1341   Michelle Walker  25.0         693000    22/01/2023   cultural
#
#    num_dependents  has_passport         city state
# 0               3         False   Stevenstad    IA
# 1               0          True  Jessicabury    NC
# 2               3          True  Salinasfort    ND
# 3               3          True  South Megan    MP
# 4               3          True   Davidburgh    CO

# %% [markdown]
# ## Travel_budget feature cleaning

# %%
df_members['travel_budget'].value_counts(dropna=False).head(5)
# Out:
# travel_budget
# 115000    6
# 571000    5
# 224000    5
# 474000    5
# 648000    5
# Name: count, dtype: int64

# %%
df_members['travel_budget'].isna().sum()
# Out:
# np.int64(0)

# %%
non_numeric = df_members[~df_members['travel_budget'].astype(str).str.replace(',', '').str.replace('$', '').str.strip().str.isnumeric()]
non_numeric[['travel_budget']]
# Out:
# Empty DataFrame
# Columns: [travel_budget]
# Index: []

# %% [markdown]
# ## Signup_date feature cleaning

# %%
df_members['signup_date'].head(10)
# Out:
# 0      17/07/2021
# 1      2024-04-06
# 2      2024-09-23
# 3    Apr 24, 2024
# 4      22/01/2023
# 5      2022-09-13
# 6    Sep 11, 2024
# 7      10/01/2025
# 8    Sep 09, 2021
# 9    Nov 19, 2022
# Name: signup_date, dtype: object

# %%
df_members['signup_date'].apply(lambda x: str(x)[:4]).value_counts()
# Out:
# signup_date
# 2023    85
# 2022    84
# 2024    76
# 2021    41
# Aug     39
#         ..
# 25/1     1
# 30/1     1
# 19/1     1
# 04/1     1
# 07/1     1
# Name: count, Length: 79, dtype: int64

# %%
df_members['signup_date'].value_counts(dropna=False)
# Out:
# signup_date
# 12/06/2024      4
# 2023-01-08      3
# 03/12/2021      3
# Aug 28, 2022    3
# 2022-11-20      3
#                ..
# 2023-08-04      1
# 30/04/2023      1
# Mar 12, 2023    1
# 2024-12-25      1
# 2024-05-25      1
# Name: count, Length: 901, dtype: int64

# %%
df = df_members.copy()

# %%
df['signup_date'] = df['signup_date'].astype(str).str.strip()

# %%
df['signup_date_clean'] = pd.NaT

# %%
mask_iso = df['signup_date'].str.match(r'^\d{4}-\d{2}-\d{2}$')
df.loc[mask_iso, 'signup_date_clean'] = pd.to_datetime(df.loc[mask_iso, 'signup_date'], format='%Y-%m-%d')

# %%
mask_dmy = df['signup_date'].str.match(r'^\d{2}/\d{2}/\d{4}$')
df.loc[mask_dmy, 'signup_date_clean'] = pd.to_datetime(df.loc[mask_dmy, 'signup_date'], format='%d/%m/%Y')

# %%
mask_named_month = df['signup_date'].str.match(r'^[A-Za-z]{3,9} \d{1,2}, \d{4}$')
df.loc[mask_named_month, 'signup_date_clean'] = pd.to_datetime(df.loc[mask_named_month, 'signup_date'], format='%b %d, %Y')

# %%
df['signup_date_clean'] = df['signup_date_clean'].dt.strftime('%Y-%m-%d')

# %%
df['signup_date_clean'].head(10)
# Out:
# 0    2021-07-17
# 1    2024-04-06
# 2    2024-09-23
# 3    2024-04-24
# 4    2023-01-22
# 5    2022-09-13
# 6    2024-09-11
# 7    2025-01-10
# 8    2021-09-09
# 9    2022-11-19
# Name: signup_date_clean, dtype: object

# %%
df['signup_date_clean'].isna().sum()
# Out:
# np.int64(0)

# %%
df.head(4)
# Out:
#    member_id              name   age  travel_budget   signup_date preference  \
# 0       1685  Michael Williams  71.0         646000    17/07/2021     luxury
# 1       1614   Danielle George  50.0         153000    2024-04-06  adventure
# 2       1602      Denise Brock  22.0         155000    2024-09-23      beach
# 3       1502      Terry Holmes  50.0         403000  Apr 24, 2024      beach
#
#    num_dependents  has_passport         city state signup_date_clean
# 0               3         False   Stevenstad    IA        2021-07-17
# 1               0          True  Jessicabury    NC        2024-04-06
# 2               3          True  Salinasfort    ND        2024-09-23
# 3               3          True  South Megan    MP        2024-04-24

# %%
df.drop(columns='signup_date', inplace=True)

# %%
df.head(5)
# Out:
#    member_id              name   age  travel_budget preference  \
# 0       1685  Michael Williams  71.0         646000     luxury
# 1       1614   Danielle George  50.0         153000  adventure
# 2       1602      Denise Brock  22.0         155000      beach
# 3       1502      Terry Holmes  50.0         403000      beach
# 4       1341   Michelle Walker  25.0         693000   cultural
#
#    num_dependents  has_passport         city state signup_date_clean
# 0               3         False   Stevenstad    IA        2021-07-17
# 1               0          True  Jessicabury    NC        2024-04-06
# 2               3          True  Salinasfort    ND        2024-09-23
# 3               3          True  South Megan    MP        2024-04-24
# 4               3          True   Davidburgh    CO        2023-01-22

# %% [markdown]
# ## Preference feature cleaning

# %%
df['preference'].unique()
# Out:
# array(['luxury', 'adventure', 'beach', 'cultural', 'nature', 'budget'],
#       dtype=object)

# %%
# no cleaning required

# %% [markdown]
# ## Num of Dependents

# %%
df['num_dependents'].unique()
# Out:
# array([3, 0, 1, 2])

# %%
type(df['num_dependents'][0])
# Out:
# numpy.int64

# %% [markdown]
# ## Has_passport?

# %%
df['has_passport'].unique()
# Out:
# array([False,  True])

# %%
df[df['has_passport'].isnull()]
# Out:
# Empty DataFrame
# Columns: [member_id, name, age, travel_budget, preference, num_dependents, has_passport, city, state, signup_date_clean]
# Index: []

# %%
df.head()
# Out:
#    member_id              name   age  travel_budget preference  \
# 0       1685  Michael Williams  71.0         646000     luxury
# 1       1614   Danielle George  50.0         153000  adventure
# 2       1602      Denise Brock  22.0         155000      beach
# 3       1502      Terry Holmes  50.0         403000      beach
# 4       1341   Michelle Walker  25.0         693000   cultural
#
#    num_dependents  has_passport         city state signup_date_clean
# 0               3         False   Stevenstad    IA        2021-07-17
# 1               0          True  Jessicabury    NC        2024-04-06
# 2               3          True  Salinasfort    ND        2024-09-23
# 3               3          True  South Megan    MP        2024-04-24
# 4               3          True   Davidburgh    CO        2023-01-22

# %% [markdown]
# ## Check for Duplicates

# %%
df[df.duplicated()]
# Out:
#      member_id                name   age  travel_budget preference  \
# 633       1818  Vanessa Stephenson  64.0         130000      beach
# 670       1242         Thomas Hart  34.0         561000      beach
# 709       1507     Lawrence Robles  65.0         372000      beach
# 728       1452       Laura Jackson  48.5         177000   cultural
# 740       1368        Jerry Carter  28.0         571000      beach
#
#      num_dependents  has_passport           city state signup_date_clean
# 633               1          True     Arnoldberg    DC        2022-06-03
# 670               3          True  Port Clifford    AZ        2022-04-02
# 709               1          True   Sandersville    MT        2023-01-18
# 728               2          True   Jenniferbury    AZ        2024-06-12
# 740               2         False   Hollyborough    MO        2023-10-01

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [member_id, name, age, travel_budget, preference, num_dependents, has_passport, city, state, signup_date_clean]
# Index: []

# %%
df.to_csv('members_clean.csv', index = False)

# %%
bucket_name = "trip-data-cleaning"

client = storage.Client()
bucket = client.bucket(bucket_name)

blob = bucket.blob('members_clean.csv')
blob.upload_from_filename('members_clean.csv')

print("Uploaded Successfully!")
# Out:
# Uploaded Successfully!

# %% [markdown]
# # Destinations.csv File Cleaning

# %%
df1 = pd.read_csv('destinations.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   destination    10 non-null     object
#  1   country        10 non-null     object
#  2   tags           10 non-null     object
#  3   avg_cost_usd   10 non-null     int64
#  4   safety_rating  10 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 532.0+ bytes

# %%
# Looking into info there are no missing values.

# %%
df1.isna().sum()
# Out:
# destination      0
# country          0
# tags             0
# avg_cost_usd     0
# safety_rating    0
# dtype: int64

# %%
df1['tags'].unique()
# Out:
# array(['budget-friendly,romantic,cultural,historic', 'luxury,beach',
#        'historic,party,beach,budget-friendly',
#        'budget-friendly,romantic,historic', 'cultural,nature,adventure',
#        'beach,budget-friendly,historic,party', 'historic,family-friendly',
#        'luxury,historic,romantic',
#        'historic,party,family-friendly,adventure',
#        'romantic,family-friendly,budget-friendly'], dtype=object)

# %% [markdown]
# ## Tags Feature cleaning

# %%
df1['tags'] = df1['tags'].astype(str).str.split(',')

# %%
df1.head()
# Out:
#   destination       country                                             tags  \
# 0      Cancun        Mexico  [budget-friendly, romantic, cultural, historic]
# 1       Paris        France                                  [luxury, beach]
# 2       Tokyo         Japan        [historic, party, beach, budget-friendly]
# 3        Bali     Indonesia            [budget-friendly, romantic, historic]
# 4   Cape Town  South Africa                    [cultural, nature, adventure]
#
#    avg_cost_usd  safety_rating
# 0         80000            4.6
# 1        502000            3.1
# 2        101000            3.9
# 3        109000            2.5
# 4        279000            4.8

# %%
df1['tags'] = df1['tags'].apply(
    lambda lst: [tag.strip().lower() for tag in lst]
)

# %%
df1.head()
# Out:
#   destination       country                                             tags  \
# 0      Cancun        Mexico  [budget-friendly, romantic, cultural, historic]
# 1       Paris        France                                  [luxury, beach]
# 2       Tokyo         Japan        [historic, party, beach, budget-friendly]
# 3        Bali     Indonesia            [budget-friendly, romantic, historic]
# 4   Cape Town  South Africa                    [cultural, nature, adventure]
#
#    avg_cost_usd  safety_rating
# 0         80000            4.6
# 1        502000            3.1
# 2        101000            3.9
# 3        109000            2.5
# 4        279000            4.8

# %%
df1.to_csv('destinations_clean.csv', index = False)

# %%
bucket_name = "trip-data-cleaning"

client = storage.Client()
bucket = client.bucket(bucket_name)

blob = bucket.blob('destinations_clean.csv')
blob.upload_from_filename('destinations_clean.csv')

print("Uploaded Successfully!")
# Out:
# Uploaded Successfully!

# %% [markdown]
# # Trips.csv File Cleaning

# %%
df2 = pd.read_csv('trips.csv')

# %%
df2.head()
# Out:
#   trip_id  member_id destination        start_date  duration_days  cost_usd  \
# 0   T1000       1685   Cape Town        2023-04-12              5    286000
# 1   T1001       1685       Banff  January 15, 2025             10    259000
# 2   T1002       1685       Banff        11/18/2024              8    268000
# 3   T1003       1685   Barcelona        04/18/2025              9    176000
# 4   T1004       1685        Rome        2025-01-29              6    232000
#
#                     activities
# 0       wine tasting, shopping
# 1       shopping, wine tasting
# 2  shopping, wine tasting, spa
# 3  wine tasting, shopping, spa
# 4       shopping, wine tasting

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3011 entries, 0 to 3010
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   trip_id        3011 non-null   object
#  1   member_id      3011 non-null   int64
#  2   destination    3011 non-null   object
#  3   start_date     3011 non-null   object
#  4   duration_days  3011 non-null   int64
#  5   cost_usd       3011 non-null   int64
#  6   activities     3011 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 164.8+ KB

# %%
df2.isna().sum()
# Out:
# trip_id          0
# member_id        0
# destination      0
# start_date       0
# duration_days    0
# cost_usd         0
# activities       0
# dtype: int64

# %% [markdown]
# ## Trip id Feature cleaning

# %%
df2[df2['trip_id'].duplicated()] # check if any duplicate primary keys
# Out:
# Empty DataFrame
# Columns: [trip_id, member_id, destination, start_date, duration_days, cost_usd, activities]
# Index: []

# %% [markdown]
# ## Destination

# %%
df2['destination'].unique()
# Out:
# array(['Cape Town', 'Banff', 'Barcelona', 'Rome', 'Bali', 'Tokyo',
#        'Cancun', 'Denver', 'Phuket', 'Paris'], dtype=object)

# %%
type(df2['destination'][0])
# Out:
# str

# %%
df2['destination'] = df2['destination'].astype(str).str.strip().str.title()

# %% [markdown]
# ## Start_date feature cleaning

# %%
df2['start_date_clean'] = pd.NaT

# %%
df2.head(2)
# Out:
#   trip_id  member_id destination        start_date  duration_days  cost_usd  \
# 0   T1000       1685   Cape Town        2023-04-12              5    286000
# 1   T1001       1685       Banff  January 15, 2025             10    259000
#
#                activities start_date_clean
# 0  wine tasting, shopping              NaT
# 1  shopping, wine tasting              NaT

# %%
mask_iso = df2['start_date'].str.match(r'^\d{4}-\d{2}-\d{2}$')
mask_dmy = df2['start_date'].str.match(r'^\d{2}/\d{2}/\d{4}$')
mask_monthname = df2['start_date'].str.match(r'^[A-Za-z]{3,9} \d{1,2}, \d{4}$')

# %%
df2.loc[mask_iso, 'start_date_clean'] = pd.to_datetime(df2.loc[mask_iso, 'start_date'], format='%Y-%m-%d')
df2.loc[mask_dmy, 'start_date_clean'] = pd.to_datetime(df2.loc[mask_dmy, 'start_date'], format='%m/%d/%Y')
df2.loc[mask_monthname, 'start_date_clean'] = pd.to_datetime(df2.loc[mask_monthname, 'start_date'], format='%B %d, %Y')

# %%
df2['start_date_clean'] = df2['start_date_clean'].dt.strftime('%Y-%m-%d')

# %%
df2.head()
# Out:
#   trip_id  member_id destination        start_date  duration_days  cost_usd  \
# 0   T1000       1685   Cape Town        2023-04-12              5    286000
# 1   T1001       1685       Banff  January 15, 2025             10    259000
# 2   T1002       1685       Banff        11/18/2024              8    268000
# 3   T1003       1685   Barcelona        04/18/2025              9    176000
# 4   T1004       1685        Rome        2025-01-29              6    232000
#
#                     activities start_date_clean
# 0       wine tasting, shopping       2023-04-12
# 1       shopping, wine tasting       2025-01-15
# 2  shopping, wine tasting, spa       2024-11-18
# 3  wine tasting, shopping, spa       2025-04-18
# 4       shopping, wine tasting       2025-01-29

# %%
df2.drop(columns='start_date', inplace=True)

# %% [markdown]
# ## Duration_days

# %%
df2[df2['duration_days'] <= 0]
# Out:
# Empty DataFrame
# Columns: [trip_id, member_id, destination, duration_days, cost_usd, activities, start_date_clean]
# Index: []

# %% [markdown]
# ## Cost_usd

# %%
df2['cost_usd'].min()
# Out:
# 64000

# %%
df2['cost_usd'].max()
# Out:
# 615000

# %%
df2.loc[df2['cost_usd'] == df2['cost_usd'].min()]
# Out:
#      trip_id  member_id destination  duration_days  cost_usd  \
# 297    T1297       1154      Cancun              3     64000
# 522    T1522       1354      Cancun              8     64000
# 917    T1917       1757      Cancun              5     64000
# 2392   T3392       1450      Cancun              7     64000
# 2617   T3617       1712      Cancun              7     64000
#
#                                  activities start_date_clean
# 297                           spa, shopping       2022-10-21
# 522                           spa, shopping       2023-12-17
# 917   food tour, museum tour, cultural show       2022-04-06
# 2392               kayaking, hiking, safari       2025-03-23
# 2617                             spa, beach       2022-09-17

# %% [markdown]
# ## Activities

# %%
df2['activities'].unique()
# Out:
# array(['wine tasting, shopping', 'shopping, wine tasting',
#        'shopping, wine tasting, spa', 'wine tasting, shopping, spa',
#        'kayaking, hiking', 'hiking, safari, kayaking',
#        'kayaking, hiking, safari', 'hiking, safari',
#        'beach, snorkeling, spa', 'snorkeling, beach', 'beach',
#        'snorkeling, spa, beach', 'spa, beach, snorkeling',
#        'cultural show, food tour, museum tour', 'snorkeling, spa',
#        'safari', 'spa', 'spa, beach', 'hiking', 'safari, kayaking',
#        'safari, hiking', 'kayaking', 'safari, hiking, kayaking',
#        'spa, snorkeling', 'beach, spa, snorkeling', 'wine tasting, spa',
#        'shopping, spa, wine tasting', 'hiking, museum tour', 'food tour',
#        'hiking, museum tour, food tour', 'hiking, kayaking',
#        'food tour, cultural show, museum tour',
#        'food tour, cultural show',
#        'museum tour, cultural show, food tour',
#        'cultural show, food tour', 'snorkeling, beach, spa', 'snorkeling',
#        'beach, spa', 'beach, snorkeling',
#        'hiking, food tour, museum tour', 'food tour, museum tour',
#        'hiking, food tour', 'spa, wine tasting', 'wine tasting',
#        'wine tasting, spa, shopping', 'hiking, kayaking, safari',
#        'kayaking, safari', 'cultural show',
#        'food tour, museum tour, cultural show', 'shopping, spa',
#        'safari, kayaking, hiking', 'spa, shopping', 'shopping',
#        'kayaking, safari, hiking', 'museum tour',
#        'museum tour, cultural show', 'food tour, museum tour, hiking',
#        'museum tour, hiking, food tour', 'museum tour, food tour',
#        'spa, wine tasting, shopping', 'museum tour, food tour, hiking',
#        'food tour, hiking', 'food tour, hiking, museum tour',
#        'spa, snorkeling, beach', 'cultural show, museum tour, food tour',
#        'cultural show, museum tour', 'museum tour, hiking',
#        'museum tour, food tour, cultural show',
#        'spa, shopping, wine tasting'], dtype=object)

# %%
df2['activities'] = df2['activities'].str.split(',')

# %%
df2['activities'] = df2['activities'].apply(
    lambda lst: [activity.strip().lower() for activity in lst]
)

# %%
df2.head()
# Out:
#   trip_id  member_id destination  duration_days  cost_usd  \
# 0   T1000       1685   Cape Town              5    286000
# 1   T1001       1685       Banff             10    259000
# 2   T1002       1685       Banff              8    268000
# 3   T1003       1685   Barcelona              9    176000
# 4   T1004       1685        Rome              6    232000
#
#                       activities start_date_clean
# 0       [wine tasting, shopping]       2023-04-12
# 1       [shopping, wine tasting]       2025-01-15
# 2  [shopping, wine tasting, spa]       2024-11-18
# 3  [wine tasting, shopping, spa]       2025-04-18
# 4       [shopping, wine tasting]       2025-01-29

# %%
df2.to_csv('trips_clean.csv', index=False)

# %%
bucket_name = "trip-data-cleaning"

client = storage.Client()
bucket = client.bucket(bucket_name)

blob = bucket.blob('trips_clean.csv')
blob.upload_from_filename('trips_clean.csv')

print("Uploaded Successfully!")
# Out:
# Uploaded Successfully!

# %% [markdown]
# # Weather.csv Cleaning

# %%
df3 = pd.read_csv('weather.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   destination      120 non-null    object
#  1   month            120 non-null    object
#  2   weather          120 non-null    object
#  3   seasonal_rating  120 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.9+ KB

# %%
df3.isna().sum()
# Out:
# destination        0
# month              0
# weather            0
# seasonal_rating    0
# dtype: int64

# %%
df3.head()
# Out:
#   destination     month weather  seasonal_rating
# 0      Cancun   January  stormy              4.1
# 1      Cancun  February   rainy              3.1
# 2      Cancun     March  cloudy              4.1
# 3      Cancun     April   rainy              4.6
# 4      Cancun       May  cloudy              4.8

# %% [markdown]
# ## Destination

# %%
df3['destination'].unique()
# Out:
# array(['Cancun', 'Paris', 'Tokyo', 'Bali', 'Cape Town', 'Denver', 'Banff',
#        'Phuket', 'Rome', 'Barcelona'], dtype=object)

# %% [markdown]
# ## Month

# %%
df3['month'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %% [markdown]
# ## Weather

# %%
df3['weather'].unique()
# Out:
# array(['stormy', 'rainy', 'cloudy', 'snowy', 'windy', 'sunny'],
#       dtype=object)

# %% [markdown]
# ## Seasonal_rating

# %%
df3['seasonal_rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df3['seasonal_rating'].min()
# Out:
# 2.5

# %%
df3['seasonal_rating'].max()
# Out:
# 5.0

# %%
df3.to_csv('weather_clean.csv', index = False)

# %%
blob = bucket.blob('weather_clean.csv')
blob.upload_from_filename('weather_clean.csv')

print("Uploaded Successfully!")
# Out:
# Uploaded Successfully!
